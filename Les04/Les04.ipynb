# %% [markdown]
# В чем принципиальное отличие гибридных рекомендательных систем от коллаборативной филтьтрации?

# %% [markdown]
# **Ответ:**
#
# Коллаборативная фильтрация не имеет никакой дополнительной информации кроме матрицы интеракций.
#
# Гибридные рекомендательные системы имеют всю ту же информацию что и коллаборативная фильтрация плюс дополнительная информация о пользователях и товарах (возраст, пол, цвет и т.п.).

# %% [markdown]
# ***

# %% [markdown]
# Приведите 2-3 примера задач, в которых необходимо использовать гибридные системы

# %% [markdown]
# **Ответ:**
#
# Не совсем понимаю вопрос. Насколько я понял из описаний, то суть гибридной системы заключается в том, что она берёт все плюсы от коллаборативной фильтрации и content-based систем.
#
# То есть по возможности стоит использовать гибридную систему.
#
# Например, выдача различных рекомендаций для соц. сетей, банков, сайтов по поиску работы и прочих компаний, которые имеют данные по своим пользователям/клиентам.

# %% [markdown]
# ***

# %% [markdown]
# Прочитайте статью про поиск на hh.ru https://habr.com/ru/company/hh/blog/347276/
#
# Нам интересна именно рекомендательная система, раздел "Производительность системы" можно пропустить.
#
# Какие основные отличия предложенной системы от тех подходов, которые мы разбирали на семинарах? Какие проблемы могут возникнуть при выводе такой модели в продакшен?

# %% [markdown]
# **Ответ:**
#
# В данной статье никакой конкретики непосредственно о том, какие используют методы для рекомендаций нет.
#
# Отличие лишь в том, что в статье рассматривается реальный пример со всеми вытекающими последствиями: необходимостью фильтраций, извлечения признаков, использования нескольких моделей для разной точности ранжирования и т. п.
#
# Проблемы, с которыми можно столкнуться при такой модели - ресурсоёмкость и не всегда высокая скорость выдачи рекомендаций пользователям.

# %% [markdown]
# ***

# %% [markdown]
# На вебинаре мы рассматривали модель LightFM (https://making.lyst.com/lightfm/docs/lightfm.html). В работе Data Scientist'а важную часть занимает research - исследование существующих архитектур и разбор научных статей, в которых они описываются. Вам предлагается изчуть оригинальную статью про LightFM https://arxiv.org/pdf/1507.08439.pdf и ответить на следующие вопросы:
# 1) Какой датасет используют авторы?
#
# 2) Что используют в качестве признаков?
#
# 3) С какими моделями сравнивают LightFM? Опишите их основные идеи кратко

# %% [markdown]
# **Ответ:**
#
# 1) тестирование модели проводили на двух датасетах: *MovieLens* и *CrossValidated*
#
# 2) в качестве признаков использовали тэги и описания/информацию о "пользователях" и "товарах". Информация о пользователях была доступна только для CrossValidated датасета.
#
# Для решения своих задач в качестве признаков использовали текстовые описательные характеристики товаров и дополнительно генерировали с помощью CNN тэги к этим товарам
#
# 3) Сравнивают с коллаборативной моделью матричной факторизации. Отличие от collaborative MF model в том, что LightFM расширяет её за счёт использования доп. признаков. Если на вход в LightFM подать только матрицу интеракций, то она сведётся к collaborative MF model.
